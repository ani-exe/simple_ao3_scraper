# %%
import requests
import pandas as pd

file_url = 'https://raw.githubusercontent.com/ani-exe/simple_ao3_scraper/main/outfile.json'
data = requests.get(file_url).json()
data = data['data']
df = pd.DataFrame(data)
df.dtypes
# Out:
# title               object
# author              object
# isAnon                bool
# isOrphan              bool
# id                  object
# rating              object
# warnings            object
# category            object
# isWip                 bool
# lastUpdated         object
# relationships       object
# isSlash               bool
# freeforms           object
# summary             object
# isSeries              bool
# seriesMeta          object
# language            object
# words                int64
# currentChapters      int64
# intendedChapters    object
# kudos                int64
# hits                 int64
# comments             int64
# bookmarks            int64
# collections          int64
# dtype: object

# %%
df
# Out:
#                                           title                     author  \
# 0                            Late night texting                   cpn86457
# 1                Hollow: A Demon!Serizawa Story            Ace_in_the_Hole
# 2                          Show them who's boss            fallenangel0666
# 3     The Ghost, the Girl, and the Little Death   La_Marionnette_Grotesque
# 4                             Our Dirty Fingers              madburnishing
# ...                                         ...                        ...
# 7076                         Double Team Tactic             orphan_account
# 7077                                          1  slutreigen (pleasejustno)
# 7078                           Brother's Keeper         allthingsunrelated
# 7079                                     senses           ekubo (apurochi)
# 7080                                 Of course.                  Anonymous
#
#       isAnon  isOrphan               id                 rating  \
# 0      False     False  /works/47353927               Explicit
# 1      False     False  /works/46349863                 Mature
# 2      False     False  /works/47351500      General Audiences
# 3      False     False  /works/47303989               Explicit
# 4      False     False  /works/37914952               Explicit
# ...      ...       ...              ...                    ...
# 7076   False      True   /works/5782909                 Mature
# 7077   False     False   /works/5613691      General Audiences
# 7078   False     False   /works/5239292              Not Rated
# 7079   False     False   /works/2535437  Teen And Up Audiences
# 7080    True     False  /works/40641009              Not Rated
#
#                                                warnings       category  isWip  \
# 0                  [Choose Not To Use Archive Warnings]          [M/M]  False
# 1                           [No Archive Warnings Apply]          [M/M]   True
# 2                  [Choose Not To Use Archive Warnings]          [F/M]  False
# 3                                            [Underage]          [F/M]  False
# 4     [Choose Not To Use Archive Warnings, Graphic D...          [M/M]   True
# ...                                                 ...            ...    ...
# 7076                                         [Underage]          [M/M]  False
# 7077                        [No Archive Warnings Apply]  [No category]  False
# 7078               [Choose Not To Use Archive Warnings]          [Gen]  False
# 7079                                         [Underage]          [M/M]  False
# 7080               [Choose Not To Use Archive Warnings]          [M/M]  False
#
#       lastUpdated  ...                                         seriesMeta  \
# 0     22 May 2023  ...                                                 []
# 1     22 May 2023  ...                                                 []
# 2     22 May 2023  ...                                                 []
# 3     22 May 2023  ...                                                 []
# 4     22 May 2023  ...                                                 []
# ...           ...  ...                                                ...
# 7076  22 Jan 2016  ...                                                 []
# 7077  02 Jan 2016  ...  [{'installment': 1, 'seriesId': '/series/38039...
# 7078  18 Nov 2015  ...                                                 []
# 7079  30 Oct 2014  ...                                                 []
# 7080  29 Jul 1969  ...                                                 []
#
#       language  words currentChapters  intendedChapters kudos   hits  \
# 0      English   1005               1                 1    26    147
# 1      English  46761              19                 ?   168   3062
# 2      English   2361               1                 1     2     22
# 3      English   6337               1                 1     7     61
# 4      English  12147              22                 ?    60   1111
# ...        ...    ...             ...               ...   ...    ...
# 7076   English   5281               1                 1   792  12713
# 7077   English    356               1                 1   206   2225
# 7078   English   1722               1                 1   252   1934
# 7079   English    266               1                 1   172   2788
# 7080   English    306               1                 1    34    769
#
#       comments  bookmarks collections
# 0            4          2           0
# 1           51         22           0
# 2            0          0           0
# 3            2          2           0
# 4            6          6           0
# ...        ...        ...         ...
# 7076        41         62           0
# 7077        15          5           0
# 7078         7         43           0
# 7079         5          5           1
# 7080         2          2           1
#
# [7081 rows x 25 columns]

# %%
# kudos / hits can be useful for another view (altho favors newer works & oneshots)
# versus overall stats which favors multichap & older
# wonder what the balance would be here.

df = df.assign(kudos_per_hits = df.kudos / df.hits)
df['lastUpdated'] = pd.to_datetime(df['lastUpdated']).apply(lambda x: x.strftime('%Y-%m-%d')if not pd.isnull(x) else '')
df['date'] = pd.to_datetime(df['lastUpdated'])
df['rating'] = df['rating'].str[:1]

df = df.assign(numSeries = df['seriesMeta'].str.len())
df
# Out:
#                                           title                     author  \
# 0                            Late night texting                   cpn86457
# 1                Hollow: A Demon!Serizawa Story            Ace_in_the_Hole
# 2                          Show them who's boss            fallenangel0666
# 3     The Ghost, the Girl, and the Little Death   La_Marionnette_Grotesque
# 4                             Our Dirty Fingers              madburnishing
# ...                                         ...                        ...
# 7076                         Double Team Tactic             orphan_account
# 7077                                          1  slutreigen (pleasejustno)
# 7078                           Brother's Keeper         allthingsunrelated
# 7079                                     senses           ekubo (apurochi)
# 7080                                 Of course.                  Anonymous
#
#       isAnon  isOrphan               id rating  \
# 0      False     False  /works/47353927      E
# 1      False     False  /works/46349863      M
# 2      False     False  /works/47351500      G
# 3      False     False  /works/47303989      E
# 4      False     False  /works/37914952      E
# ...      ...       ...              ...    ...
# 7076   False      True   /works/5782909      M
# 7077   False     False   /works/5613691      G
# 7078   False     False   /works/5239292      N
# 7079   False     False   /works/2535437      T
# 7080    True     False  /works/40641009      N
#
#                                                warnings       category  isWip  \
# 0                  [Choose Not To Use Archive Warnings]          [M/M]  False
# 1                           [No Archive Warnings Apply]          [M/M]   True
# 2                  [Choose Not To Use Archive Warnings]          [F/M]  False
# 3                                            [Underage]          [F/M]  False
# 4     [Choose Not To Use Archive Warnings, Graphic D...          [M/M]   True
# ...                                                 ...            ...    ...
# 7076                                         [Underage]          [M/M]  False
# 7077                        [No Archive Warnings Apply]  [No category]  False
# 7078               [Choose Not To Use Archive Warnings]          [Gen]  False
# 7079                                         [Underage]          [M/M]  False
# 7080               [Choose Not To Use Archive Warnings]          [M/M]  False
#
#      lastUpdated  ... currentChapters  intendedChapters kudos   hits  \
# 0     2023-05-22  ...               1                 1    26    147
# 1     2023-05-22  ...              19                 ?   168   3062
# 2     2023-05-22  ...               1                 1     2     22
# 3     2023-05-22  ...               1                 1     7     61
# 4     2023-05-22  ...              22                 ?    60   1111
# ...          ...  ...             ...               ...   ...    ...
# 7076  2016-01-22  ...               1                 1   792  12713
# 7077  2016-01-02  ...               1                 1   206   2225
# 7078  2015-11-18  ...               1                 1   252   1934
# 7079  2014-10-30  ...               1                 1   172   2788
# 7080  1969-07-29  ...               1                 1    34    769
#
#       comments bookmarks collections  kudos_per_hits       date numSeries
# 0            4         2           0        0.176871 2023-05-22         0
# 1           51        22           0        0.054866 2023-05-22         0
# 2            0         0           0        0.090909 2023-05-22         0
# 3            2         2           0        0.114754 2023-05-22         0
# 4            6         6           0        0.054005 2023-05-22         0
# ...        ...       ...         ...             ...        ...       ...
# 7076        41        62           0        0.062298 2016-01-22         0
# 7077        15         5           0        0.092584 2016-01-02         1
# 7078         7        43           0        0.130300 2015-11-18         0
# 7079         5         5           1        0.061693 2014-10-30         0
# 7080         2         2           1        0.044213 1969-07-29         0
#
# [7081 rows x 28 columns]

# %%
df.describe()
# Out:
#               words  currentChapters         kudos           hits  \
# count  7.081000e+03      7081.000000   7081.000000    7081.000000
# mean   6.596370e+03         2.177376    207.094196    2183.903827
# std    6.793271e+04        13.032083    395.374569    6102.839445
# min    1.000000e+02         1.000000      0.000000      11.000000
# 25%    1.149000e+03         1.000000     47.000000     486.000000
# 50%    2.270000e+03         1.000000    109.000000    1067.000000
# 75%    4.947000e+03         1.000000    225.000000    2239.000000
# max    5.450041e+06      1058.000000  12515.000000  387030.000000
#
#           comments    bookmarks  collections  kudos_per_hits    numSeries
# count  7081.000000  7081.000000  7081.000000     7081.000000  7081.000000
# mean     22.996469    23.259992     0.071883        0.110377     0.208304
# std     102.274616    70.866579     0.299814        0.050664     0.416087
# min       0.000000     0.000000     0.000000        0.000000     0.000000
# 25%       4.000000     3.000000     0.000000        0.072013     0.000000
# 50%       8.000000     8.000000     0.000000        0.105263     0.000000
# 75%      18.000000    21.000000     0.000000        0.142578     0.000000
# max    5887.000000  2705.000000     8.000000        0.436170     2.000000

# %%
str_df = df
str_df['ffstring'] = [','.join(map(str, l)) for l in df['freeforms']]

# %%
numeric_stats = ["words", "kudos", "hits", "comments", "bookmarks", "kudos_per_hits"]
rating_per_avg_stat = df[["rating"] + numeric_stats].groupby("rating").mean()
rating_per_avg_stat
# Out:
#                words       kudos         hits   comments  bookmarks  \
# rating
# E        6351.916667  208.468254  3470.637897  17.413690  18.721230
# G        2842.076756  206.971398  1633.273353  15.129254  22.013758
# M       21124.549822  181.402135  2329.195730  38.500000  20.448399
# N        3712.113684  126.458947  1196.126316  10.926316  11.951579
# T        8276.649077  229.827177  2452.748901  33.716359  29.842568
#
#         kudos_per_hits
# rating
# E             0.061170
# G             0.134546
# M             0.084678
# N             0.107478
# T             0.109791

# %%
rating_per_avg_stat["kudos"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["comments"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["bookmarks"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["kudos_per_hits"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["hits"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
# do wips do worse than completed fics?
iswip_per_avg_stat = df[["isWip"] + numeric_stats].groupby("isWip").mean()
iswip_per_avg_stat
# Out:
#               words       kudos         hits   comments  bookmarks  \
# isWip
# False   4286.425932  215.419492  2126.390339  18.778136  23.717797
# True   18136.313294  165.502964  2471.227773  44.070279  20.972904
#
#        kudos_per_hits
# isWip
# False        0.115394
# True         0.085316

# %%
#oneshots only
oneshot_avg_stats = df[df["intendedChapters"] == "1"]
oneshot_avg_stats.describe()
# Out:
#               words  currentChapters        kudos          hits     comments  \
# count   5192.000000           5192.0  5192.000000   5192.000000  5192.000000
# mean    2601.641371              1.0   186.095532   1705.005586    11.010401
# std     2676.284349              0.0   292.072530   2487.647836    15.048905
# min      100.000000              1.0     0.000000     18.000000     0.000000
# 25%      988.000000              1.0    48.000000    471.000000     3.000000
# 50%     1731.000000              1.0   108.000000    998.000000     7.000000
# 75%     3230.250000              1.0   215.000000   2006.000000    14.000000
# max    29089.000000              1.0  6433.000000  55937.000000   365.000000
#
#          bookmarks  collections  kudos_per_hits    numSeries
# count  5192.000000  5192.000000     5192.000000  5192.000000
# mean     18.455701     0.075501        0.118919     0.224961
# std      45.963199     0.277730        0.052376     0.428526
# min       0.000000     0.000000        0.000000     0.000000
# 25%       3.000000     0.000000        0.080868     0.000000
# 50%       7.000000     0.000000        0.117133     0.000000
# 75%      18.000000     0.000000        0.152174     0.000000
# max    1610.000000     4.000000        0.436170     2.000000

# %%
#multichap fics only
multichap_avg_stats = df[df["intendedChapters"] != "1"] # could be a number or a '?'
multichap_avg_stats.describe()
# Out:
#               words  currentChapters         kudos           hits  \
# count  1.889000e+03      1889.000000   1889.000000    1889.000000
# mean   1.757606e+04         5.413446    264.809952    3500.176813
# std    1.308492e+05        24.951798    589.161397   10967.609052
# min    1.220000e+02         1.000000      0.000000      11.000000
# 25%    2.934000e+03         2.000000     43.000000     565.000000
# 50%    6.613000e+03         3.000000    112.000000    1331.000000
# 75%    1.579600e+04         6.000000    268.000000    3190.000000
# max    5.450041e+06      1058.000000  12515.000000  387030.000000
#
#           comments    bookmarks  collections  kudos_per_hits    numSeries
# count  1889.000000  1889.000000  1889.000000     1889.000000  1889.000000
# mean     55.940709    36.464796     0.061938        0.086899     0.162520
# std     192.669960   113.076362     0.353369        0.036486     0.376133
# min       0.000000     0.000000     0.000000        0.000000     0.000000
# 25%       6.000000     3.000000     0.000000        0.060818     0.000000
# 50%      17.000000    11.000000     0.000000        0.082792     0.000000
# 75%      44.000000    29.000000     0.000000        0.109034     0.000000
# max    5887.000000  2705.000000     8.000000        0.280899     2.000000

# %%
#do fics in series have more engagement?
df[df["isSeries"]].describe()
# Out:
#               words  currentChapters        kudos          hits     comments  \
# count  1.446000e+03      1446.000000  1446.000000   1446.000000  1446.000000
# mean   1.055712e+04         2.739281   221.632780   2465.248271    30.132089
# std    1.481766e+05        28.056797   343.638071   4509.764832   177.930276
# min    1.000000e+02         1.000000     2.000000     25.000000     0.000000
# 25%    1.063000e+03         1.000000    66.000000    640.250000     4.000000
# 50%    2.094500e+03         1.000000   127.500000   1339.000000     9.000000
# 75%    4.892000e+03         1.000000   243.000000   2679.000000    19.000000
# max    5.450041e+06      1058.000000  4834.000000  66105.000000  5887.000000
#
#          bookmarks  collections  kudos_per_hits    numSeries
# count  1446.000000  1446.000000     1446.000000  1446.000000
# mean     20.952282     0.064315        0.104913     1.020055
# std      56.274240     0.274673        0.041359     0.140238
# min       0.000000     0.000000        0.005294     1.000000
# 25%       3.000000     0.000000        0.077560     1.000000
# 50%       8.000000     0.000000        0.102396     1.000000
# 75%      19.750000     0.000000        0.130216     1.000000
# max    1206.000000     4.000000        0.301471     2.000000

# %%
# let's get the bar graph of all relationships in the tag and see if we need to fix some tags
from itertools import chain
from collections import Counter
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 5]


rel_only = df[df['relationships'].str.len() > 0]
print(((rel_only['relationships'].size / df.relationships.size) *100),'% of MP100 fics contain relationship tags')
# Out:
# 87.37466459539614 % of MP100 fics contain relationship tags

# %%
ls_rel = rel_only.relationships.tolist()
ctr = Counter(chain.from_iterable(ls_rel))
ctr.most_common(50)

y = [count for tag, count in ctr.most_common(50)]
x = [tag for tag, count in ctr.most_common(50)]

plt.bar(x, y, color='blue')
plt.title("Relationship Tag Frequency")
plt.ylabel("Frequency of Tag")
plt.xticks(rotation=90)
plt.show()

# %%
ctr.most_common(50)
# Out:
# [('Reigen Arataka/Serizawa Katsuya', 1386),
#  ('Kageyama "Mob" Shigeo & Reigen Arataka', 944),
#  ('Hanazawa Teruki/Kageyama "Mob" Shigeo', 920),
#  ('Kageyama "Mob" Shigeo/Reigen Arataka', 687),
#  ('Kageyama Ritsu/Suzuki Shou', 666),
#  ('Kageyama Ritsu & Kageyama "Mob" Shigeo', 504),
#  ('Hanazawa Teruki & Kageyama "Mob" Shigeo', 333),
#  ('Reigen Arataka & Serizawa Katsuya', 283),
#  ('Dimple/Reigen Arataka', 269),
#  ('Kageyama Ritsu/Kageyama "Mob" Shigeo', 253),
#  ('Kageyama Ritsu & Suzuki Shou', 207),
#  ('Hanazawa Teruki & Reigen Arataka', 188),
#  ('Reigen Arataka/Reader', 183),
#  ('Dimple & Reigen Arataka', 148),
#  ('Hanazawa Teruki/Shimazaki Ryou', 139),
#  ('Kageyama Ritsu & Reigen Arataka', 135),
#  ('Dimple & Kageyama "Mob" Shigeo', 122),
#  ('Kurata Tome & Reigen Arataka', 105),
#  ('Minegishi Toshiki/Shimazaki Ryou', 79),
#  ('Kageyama Ritsu & Hanazawa Teruki', 72),
#  ('Kageyama "Mob" Shigeo & Kurata Tome', 71),
#  ('Kageyama "Mob" Shigeo & Serizawa Katsuya', 68),
#  ('Kageyama Ritsu/Reigen Arataka', 63),
#  ('No Romantic Relationship(s)', 62),
#  ('Kageyama "Mob" Shigeo & Suzuki Shou', 61),
#  ('Serizawa Katsuya & Suzuki Shou', 56),
#  ('Hanazawa Teruki/Kageyama Ritsu', 54),
#  ('Reigen Arataka/Original Character(s)', 51),
#  ('Hanazawa Teruki & Suzuki Shou', 50),
#  ('Dimple/Reigen Arataka/Serizawa Katsuya', 50),
#  ('Reigen Arataka & Reader', 47),
#  ('Kurata Tome/Takane Tsubomi', 46),
#  ('Kageyama "Mob" Shigeo & Takane Tsubomi', 45),
#  ('Kageyama Ritsu/Takenaka Momozou', 45),
#  ('Kurata Tome & Serizawa Katsuya', 41),
#  ('Gouda Musashi/Kageyama "Mob" Shigeo', 37),
#  ('Kageyama "Mob" Shigeo/Reader', 36),
#  ('Suzuki Shou & Suzuki Touichirou', 36),
#  ('Reigen Arataka & Suzuki Shou', 36),
#  ('Kageyama "Mob" Shigeo/Takenaka Momozou', 34),
#  ('Claw Security Guard/Dimple/Reigen Arataka', 33),
#  ('Serizawa Katsuya/Suzuki Touichirou', 33),
#  ('Kageyama "Mob" Shigeo/Suzuki Shou', 32),
#  ('Kageyama "Mob" Shigeo/Takane Tsubomi', 31),
#  ('Reigen Arataka & Everyone', 30),
#  ('Minor or Background Relationship(s)', 30),
#  ('Kageyama "Mob" Shigeo/Mogami Keiji', 29),
#  ('Serizawa Katsuya & Suzuki Touichirou', 28),
#  ('Emi/Kageyama "Mob" Shigeo', 26),
#  ('Claw Security Guard/Reigen Arataka', 26)]

# %%
ctr.most_common()[-100:-1]
# Out:
# [('Asagiri Minori & Shimazaki Ryou', 1),
#  ('Minegishi Toshiki/Original Characters(s)', 1),
#  ('Kamuro Shinji/Original Character(s)', 1),
#  ('(IMPLIED)', 1),
#  ('Serizawa Katsuya/Original Female Character(s)', 1),
#  ('Serizawa Katsuya/Shibata Hiroshi', 1),
#  ('Poly Super 5', 1),
#  ('cuz im not nasty', 1),
#  ('all is platonic', 1),
#  ('though maybe some ships are implied', 1),
#  ('implied sorta kinda. its fine', 1),
#  ('Claw & Serizawa Katsuya (Mob Psycho 100)', 1),
#  ('ritshou and serirei are VERY backseat tho', 1),
#  ('Mezato Ichi/Takenaka Momozou', 1),
#  ('(mentioned--mob isnt actually in this one)', 1),
#  ('super five boyfriend squad also', 1),
#  ('but its just kinda mentioned', 1),
#  ('Asagiri Minori & Emi', 1),
#  ("see that '&'*q* yeah*d* no pedo ships in my good christian minecraft server",
#   1),
#  ('Hoshino Takeshi/Original Female Character(s)', 1),
#  ('Hatori Nozomu/Reader', 1),
#  ('Kurata Tome/Reader', 1),
#  ('Kageyama Ritsu - Relationship', 1),
#  ('Joseph/Udo (Mob Psycho 100)', 1),
#  ('Joseph/Minegishi Toshiki (Mob Psycho 100)', 1),
#  ('Joseph/Serizawa Katsuya (Mob Psycho 100)', 1),
#  ('but they on the side', 1),
#  ('ritsu mostly gives mob terrible dating advice', 1),
#  ("they're the abnormal uncles of the story", 1),
#  ('No Romantic Relationships - Relationship', 1),
#  ('Canon Relationships - Relationship', 1),
#  ('Mikoshiba Seijuurou/Ryuugazaki Rei', 1),
#  ('Mukai (Mob Psycho 100) & Everyone', 1),
#  ('Kageyama Ritsu & Original Female Character(s)', 1),
#  ("but only if you squint my dude it's not really there", 1),
#  ('the ritshou and tomichi are implied', 1),
#  ('Hanazawa Teruki & Kurata Tome & Suzuki Shou', 1),
#  ('Mogami Keiji/Suzuki Touichirou', 1),
#  ('Others mentioned', 1),
#  ('Student/ Teacher - Relationship', 1),
#  ('Family - Relationship', 1),
#  ('Gouda Musashi/Kageyama "Mob" Shigeo/Onigawara Tenga', 1),
#  ('Kageyama "Mob" Shigeo/Onigawara Tenga', 1),
#  ('implied relationships - Relationship', 1),
#  ('Tetsuo Isari/Jun Isari', 1),
#  ('Shinra Banshomarou/Reader', 1),
#  ('Kageyama Ritsu & Tsuchiya', 1),
#  ('Inukawa Mameta/Kageyama "Mob" Shigeo', 1),
#  ('Reigen Arataka/Shinra Banshomaru', 1),
#  ('Reigen Arataka/Sakurai Yuusuke', 1),
#  ('Kageyama "Mob" Shigeo/Koyama Megumu', 1),
#  ('Kageyama Ritsu/Koyama Megumu', 1),
#  ('Dimple/LOL Cult Leader (Mob Psycho 100)', 1),
#  ('Kamuro Shinji/Reader', 1),
#  ('Everyone is friends with everyone', 1),
#  ('Or it will be - Relationship', 1),
#  ('Can be seen as romantic but it’s nothing blatant', 1),
#  ('Inukawa Mameta/Onigawara Tenga', 1),
#  ('& the othrs but that was the most fun to write', 1),
#  ('Kurata Tome & Kurosaki Rei & Mezato Ichi & Takane Tsubomi', 1),
#  ('can be read as ship - Relationship', 1),
#  ('Hanazawa Teruki/Kageyama Ritsu/Takenaka Momozou', 1),
#  ('Esper Squad - Relationship', 1),
#  ('(no romo tho)', 1),
#  ('Hanazawa Teruki & Kurosaki Rei', 1),
#  ('Katsuya', 1),
#  ('Kageyama "Mob" Shigeo/Mogami Keiji/Reigen Arataka', 1),
#  ('Hanazawa Teruki/Serizawa Katsuya/Suzuki Touichirou', 1),
#  ('Hanazawa Teruki & Hanazawa Teruki', 1),
#  ("tsuchiya's like a parent but not quite", 1),
#  ('shes getting there', 1),
#  ('Hanazawa Teruki & Mezato Ichi', 1),
#  ('more but im so fcking tired', 1),
#  ('Hanazawa Teruki/Takenaka Momozou', 1),
#  ('Kageyama Ritsu/Suzuki Shou/Suzuki Touichirou', 1),
#  ('Hanazawa Teruki/Minegishi Toshiki/Shimazaki Ryou', 1),
#  ('Asahi Gou/Hanazawa Teruki', 1),
#  ('Ishiguro/Suzuki Touichirou', 1),
#  ('Kageyama Ritsu & Takenaka', 1),
#  ('Kurata Tome & Tokugawa', 1),
#  ('Claw Security Guard/Serizawa Katsuya', 1),
#  (':( - Relationship', 1),
#  ("Suzuki Shou's Mother/Tsuchiya", 1),
#  ('Ambiguous or Implied Relationship(s)', 1),
#  ('Kamuro Shinji & Takane Tsubomi', 1),
#  ("It's like - Relationship", 1),
#  ('Asagiri Minori/Kurosaki Rei', 1),
#  ('Tsuchiya (Mob Psycho 100)/Other(s)', 1),
#  ('only if you squint', 1),
#  ('more platonic if anything', 1),
#  ('Mariko/Onigawara Tenga', 1),
#  ('Mariko & Onigawara Tenga', 1),
#  ('(ok but . no incest yall tahts nasty as hell)', 1),
#  ('Dimple/Matsuo (Mob Psycho 100)', 1),
#  ('Hanazawa Teruki/Takane Tsubomi', 1),
#  ('Dimple/Reigen Arataka/Reader', 1),
#  ('Hunting a monster', 1),
#  ('comedy - Relationship', 1),
#  ('Supernatural humans', 1)]

# %%
# poly relationships frequency counter
d = dict(ctr)
d = {key: d[key] for key in d.keys() if key.count('/') > 1}
sorted(d.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('Dimple/Reigen Arataka/Serizawa Katsuya', 50),
#  ('Claw Security Guard/Dimple/Reigen Arataka', 33),
#  ('Kageyama Ritsu/Kageyama "Mob" Shigeo/Reigen Arataka', 13),
#  ('Claw Security Guard/Dimple/Reigen Arataka/Serizawa Katsuya', 9),
#  ('Kageyama Ritsu/Suzuki Shou/Takenaka Momozou', 5),
#  ('Hanazawa Teruki/Kageyama "Mob" Shigeo/Takenaka Momozou', 5),
#  ('Hanazawa Teruki/Kageyama Ritsu/Kageyama "Mob" Shigeo/Suzuki Shou', 4),
#  ('Reigen Arataka/Serizawa Katsuya/Reader', 2),
#  ('Dimple/Kageyama "Mob" Shigeo/Reigen Arataka', 2),
#  ('Kageyama "Mob" Shigeo/Reigen Arataka/Serizawa Katsuya', 2),
#  ('Dimple (Mob Psycho 100)/Kageyama "Mob" Shigeo/Reigen Arataka', 2),
#  ('Hanazawa Teruki/Kageyama "Mob" Shigeo/Takane Tsubomi', 2),
#  ('Dimple/Reigen Arataka/Other(s)', 2),
#  ('Dimple/Kageyama Ritsu/Kageyama "Mob" Shigeo/Reigen Arataka', 1),
#  ('Hanazawa Teruki/Kageyama Ritsu/Suzuki Shou', 1),
#  ('Kageyama "Mob" Shigeo/Reigen Arataka/Takane Tsubomi', 1),
#  ('Dimple/Kageyama "Mob" Shigeo/You', 1),
#  ('Hanazawa Teruki/Kageyama Ritsu/Kageyama "Mob" Shigeo', 1),
#  ('Reigen Arataka/Serizawa Katsuya/Shinra Banshomaru', 1),
#  ('Matsuo (Mob Psycho 100)/Minegishi Toshiki/Mogami Keiji', 1),
#  ('Reigen Arataka/Serizawa Katsuya/Serizawa Katsuya', 1),
#  ('Gouda Musashi/Kageyama "Mob" Shigeo/Onigawara Tenga', 1),
#  ('Hanazawa Teruki/Kageyama Ritsu/Takenaka Momozou', 1),
#  ('Kageyama "Mob" Shigeo/Mogami Keiji/Reigen Arataka', 1),
#  ('Hanazawa Teruki/Serizawa Katsuya/Suzuki Touichirou', 1),
#  ('Kageyama Ritsu/Suzuki Shou/Suzuki Touichirou', 1),
#  ('Hanazawa Teruki/Minegishi Toshiki/Shimazaki Ryou', 1),
#  ('Dimple/Reigen Arataka/Reader', 1)]

# %%
# platonic relationships only
rel_no_slash = rel_only[rel_only['isSlash'] == False]
rel_no_slash
# Out:
#                                     title              author  isAnon  \
# 2                    Show them who's boss     fallenangel0666   False
# 6                Guess it can’t be helped  alternativeaccount   False
# 10                               Causeway      splendidparrot   False
# 12    The End of the World as You Know It          RainCavity   False
# 15                 Defined by the Absence              wyrvel   False
# ...                                   ...                 ...     ...
# 7047  Sometimes, it's not a happy ending.      orphan_account   False
# 7050                                Gooze      orphan_account   False
# 7051                          Contentment                wuwu   False
# 7058                                Green                Sifl   False
# 7075                          Snap/Rewind       bikeaesthetic   False
#
#       isOrphan               id rating  \
# 2        False  /works/47351500      G
# 6        False  /works/47096146      T
# 10       False  /works/46239952      M
# 12       False  /works/16716950      T
# 15       False  /works/43247010      T
# ...        ...              ...    ...
# 7047      True   /works/7757914      T
# 7050      True   /works/7717465      G
# 7051     False   /works/7719790      T
# 7058     False   /works/7564429      T
# 7075     False   /works/3864454      T
#
#                                                warnings       category  isWip  \
# 2                  [Choose Not To Use Archive Warnings]          [F/M]  False
# 6     [Choose Not To Use Archive Warnings, Graphic D...     [Gen, M/M]   True
# 10                 [Choose Not To Use Archive Warnings]          [M/M]   True
# 12                          [No Archive Warnings Apply]          [Gen]   True
# 15                          [No Archive Warnings Apply]          [Gen]   True
# ...                                                 ...            ...    ...
# 7047                            [Major Character Death]          [Gen]  False
# 7050                        [No Archive Warnings Apply]          [Gen]  False
# 7051                        [No Archive Warnings Apply]          [Gen]  False
# 7058                        [No Archive Warnings Apply]          [Gen]  False
# 7075                   [Graphic Depictions Of Violence]  [No category]  False
#
#      lastUpdated  ... intendedChapters  kudos   hits comments  bookmarks  \
# 2     2023-05-22  ...                1      2     22        0          0
# 6     2023-05-22  ...                ?     15    147        0          0
# 10    2023-05-21  ...                ?    183   1925       87         13
# 12    2023-05-21  ...               34    543  16613      308        153
# 15    2023-05-20  ...                ?    566  17147      160        158
# ...          ...  ...              ...    ...    ...      ...        ...
# 7047  2016-08-13  ...                1    113   1617       13          5
# 7050  2016-08-09  ...                1    628   7391       12         64
# 7051  2016-08-09  ...                1   2114  19033      135        230
# 7058  2016-07-23  ...                1    450   4998       32         45
# 7075  2016-01-31  ...                3    707   7077       36        103
#
#      collections kudos_per_hits       date  numSeries  \
# 2              0       0.090909 2023-05-22          0
# 6              0       0.102041 2023-05-22          0
# 10             0       0.095065 2023-05-21          0
# 12             0       0.032685 2023-05-21          0
# 15             0       0.033009 2023-05-20          0
# ...          ...            ...        ...        ...
# 7047           0       0.069882 2016-08-13          0
# 7050           0       0.084968 2016-08-09          0
# 7051           1       0.111070 2016-08-09          1
# 7058           0       0.090036 2016-07-23          1
# 7075           1       0.099901 2016-01-31          0
#
#                                                ffstring
# 2     Self Confidence,Dominance,Jealousy,Established...
# 6     werewolf serizawa,reigen doesnt know serizawa ...
# 10     Coming Out,Getting Together,Aged-Up Character(s)
# 12    Canon Compliant,Claw isn't done yet,government...
# 15    Alternate Universe - Canon Divergence,Chronic ...
# ...                                                 ...
# 7047  hey angst bros this fandom needs more of it,bc...
# 7050  obligatory sickfic,Sickfic,uhhhhhhhhh,anti-fas...
# 7051  Adoption,reigen is a good guy give him a break...
# 7058  Brotherly dynamic,ritsu angst,dammit ritsu,tom...
# 7075  Blood and Gore,Violence,Recovery,Mogami Keiji ...
#
# [2172 rows x 29 columns]

# %%
sr = str_df[str_df['relationships'].apply(lambda x: 'Reigen Arataka/Serizawa Katsuya' in x)]
sr["comments"].sum()
# Out:
# 42922

# %%
tm = df[df['relationships'].apply(lambda x: 'Hanazawa Teruki/Kageyama "Mob" Shigeo' in x)]
tm["words"].sum()
# Out:
# 8522638

# %%
rm = df[df['relationships'].apply(lambda x: 'Kageyama "Mob" Shigeo/Reigen Arataka' in x)]
rm["comments"].sum()
# Out:
# 15835

# %%
rs = df[df['relationships'].apply(lambda x: 'Kageyama Ritsu/Suzuki Shou'in x)]
rs["comments"].sum()
# Out:
# 20914

# %%
df["kudos"].sum()
# Out:
# 1466434

# %%
366948 / 1466434
# Out:
# 0.25023151399926624

# %%
2172 / 7081
# Out:
# 0.3067363366756108

# %%
ls_free = df.freeforms.tolist()
ctr = Counter(chain.from_iterable(ls_free))
ctr.most_common(50)

y = [count for tag, count in ctr.most_common(50)]
x = [tag for tag, count in ctr.most_common(50)]

plt.bar(x, y, color='blue')
plt.title("Freeform Tag Frequency")
plt.ylabel("Frequency of Tag")
plt.xticks(rotation=90)
plt.show()

# %%
tm_free = tm.freeforms.tolist()
ctr = Counter(chain.from_iterable(tm_free))
ctr.most_common(50)

y = [count for tag, count in ctr.most_common(50)]
x = [tag for tag, count in ctr.most_common(50)]

plt.bar(x, y, color='blue')
plt.title("Freeform Tag Frequency (TeruMob)")
plt.ylabel("Frequency of Tag")
plt.xticks(rotation=90)
plt.show()

# %%
# authors by word count in mp100
author_words_sum = df[['author','words']].groupby('author').sum()
author_words_sum.sort_values('words', ascending=False)[0:50]
# Out:
#                          words
# author
# Green_Kneesocks        8082176
# orphan_account         1513441
# tinkertoysdamn          684669
# ToastyToaster22         557219
# Anonymous               452228
# Phantomrose96           372314
# tsukkisaur              369363
# shcherbatskayas         344542
# toyotas                 336922
# W3LTERW8                328676
# snowtears               301727
# beefstatic              287397
# quiveringpalm           274706
# Meowcatsreader          265167
# Janekfan                264230
# Sentient_Fractal        262430
# asphyxeno               247455
# silvercistern           229684
# carnation               228829
# Latenightramen          223495
# TonoRadish              222955
# RainyMeadows            209438
# Kas0114                 208733
# BeyondTheClouds777      206003
# RainCavity              195881
# Hino                    192539
# skeilig                 187008
# Copyspaghetti           185979
# Unpopular_shipper       177199
# Philiah                 175059
# BadonKaDank             172639
# ruthwrites              167053
# madburnishing           165908
# angeltalk               164699
# Serenlyss               161918
# lunarblossoms           161824
# Aesoleucian             160426
# SoHoldMeTight           157946
# Seruspica               156983
# suitablyskippy          156000
# BinaryDreams1010        153946
# ch_am                   151391
# destituteDenouement     149748
# SpiritusRex             149491
# reigreitz (reitziluz)   146435
# mochiwrites             146149
# snapdragonsuplex        138064
# crookedturtle           138025
# bobmoss                 137740
# OOberman                137606

# %%
# authors in mp100
author_words_sum = df[['author'] + numeric_stats].groupby('author').sum()
author_words_sum.sort_values('kudos', ascending=False)[0:50]
# Out:
#                          words  kudos    hits  comments  bookmarks  \
# author
# orphan_account         1513441  72016  788877      5679       7110
# tinkertoysdamn          684669  32091  345953      4937       3420
# Janekfan                264230  29041  323795      1336       1533
# skeilig                 187008  25052  196103      1996       2878
# ruthwrites              167053  24744  204542      2071       3565
# BeyondTheClouds777      206003  24698  160461      1380       3316
# snowtears               301727  23837  249377      2780       2641
# suitablyskippy          156000  19940  177932      1563       4170
# W3LTERW8                328676  19515  170923      1408       2129
# Phantomrose96           372314  17717  425468      3558       3574
# ToastyToaster22         557219  16705  157247      3524       2121
# asphyxeno               247455  15649  178947      1579       1656
# UncannyCookie           110269  15471  179849      2098       2041
# SpiritusRex             149491  14150  108542      1797       2228
# beefstatic              287397  14069  104965      1283       1328
# shcherbatskayas         344542  13942  107164      1562       1730
# Anonymous               452228  13384  168290      1309       1243
# Hino                    192539  12353   73921       598       1261
# bobmoss                 137740  11473  106952      1664       1876
# Ravenesta                46186  10959   97178       571       1955
# eggio                   118537   9055   70114       376        886
# fireflysummers_ao3       50393   8698   68643       781       1096
# NotHereForIt             37574   7969   56798       359       1587
# tentacleboye             97802   7939   62037       458        769
# mochiwrites             146149   7756   67155       412        745
# Frecklefrog              77659   7717   86775      1469       1578
# LogicalBookThief         40523   7684   88540       776       1174
# LucoLoco                 77931   7523   80589       424        556
# SparkyFrootloops         98059   7486   60808      1066        623
# Sifl                     43082   7190   72090       642        748
# reigreitz (reitziluz)   146435   6735   69391       991        678
# krypkaktus (Regndoft)    49930   6518   58074       362        575
# amaranthinecanicular     19939   6474   40435       462       1374
# heihua                    2108   6176   38529       136        534
# crookedturtle           138025   5980   59807      1475       1158
# shrikesthorn             43317   5888   44681       257        571
# mustdang100              72051   5734   55721       945        823
# taizi                    12513   5506   47610       443       1115
# twitchtipthegnawer       47103   5472   81767       318        456
# determination           135823   5376   38810       481        559
# InfiniteTeal             74845   5253   91891       216        419
# wuwu                     21552   5237   41699       317        486
# pinstripedJackalope     134291   5033   54726      1031        530
# sukikobold               36459   5006   37442       192        498
# derogatory               59488   4955   73048       283        621
# Originia                 49090   4846   58137       704       1008
# hmmeid                   75934   4841   49302       437        428
# WingSongHalo             75757   4766   42334       378        624
# ch_am                   151391   4709   54925      1568        768
# Approachingthedogpark    77101   4517   46375       253        511
#
#                        kudos_per_hits
# author
# orphan_account              39.107104
# tinkertoysdamn               9.158378
# Janekfan                    14.132892
# skeilig                      3.799676
# ruthwrites                   1.802082
# BeyondTheClouds777           7.510266
# snowtears                    4.239904
# suitablyskippy               2.274325
# W3LTERW8                     9.734558
# Phantomrose96                0.167671
# ToastyToaster22              4.171868
# asphyxeno                    4.401113
# UncannyCookie                0.767821
# SpiritusRex                  2.433189
# beefstatic                  10.978380
# shcherbatskayas              7.564992
# Anonymous                   11.355981
# Hino                        17.370536
# bobmoss                      1.686351
# Ravenesta                    0.285254
# eggio                        3.506406
# fireflysummers_ao3           2.513340
# NotHereForIt                 0.776731
# tentacleboye                 3.093334
# mochiwrites                  4.124546
# Frecklefrog                  0.502795
# LogicalBookThief             0.338763
# LucoLoco                     2.942989
# SparkyFrootloops             6.060248
# Sifl                         2.877538
# reigreitz (reitziluz)        1.767140
# krypkaktus (Regndoft)        2.580273
# amaranthinecanicular         0.639063
# heihua                       0.319267
# crookedturtle                1.070415
# shrikesthorn                 1.470312
# mustdang100                  1.214567
# taizi                        0.115648
# twitchtipthegnawer           0.920478
# determination                4.387157
# InfiniteTeal                 0.520791
# wuwu                         0.386708
# pinstripedJackalope          1.763354
# sukikobold                   1.980940
# derogatory                   0.423524
# Originia                     0.312728
# hmmeid                       3.945126
# WingSongHalo                 0.953810
# ch_am                        1.188564
# Approachingthedogpark        1.499497

# %%
# ritshou main vs ritshou as background (grain of salt with this)
# rs from earlier as all ritshou
# only_rs = rs[rs['relationships'].count("/") == 1]
# i think i need to convert these to multiindices? needs more work here to isolate ritshou

# %%
# trans seri
import re
str_df[str_df.ffstring.str.contains('Trans Serizawa Katsuya|Trans Male Serizawa Katsuya|Trans Seri|Trans Serizawa', regex=True, flags=re.IGNORECASE)]
# Out:
#                                                   title  \
# 16                                        Only With You
# 212                                  Mutual Destruction
# 491                                           warm glow
# 554                                     Trial and Error
# 793                                   whats your story?
# 864                              Perpetual Mild Illness
# 1195                                       Broccoli Sex
# 1449               Reigen’s (Boyfriend Special) Massage
# 1563                            Best Birthday Gift Ever
# 1765                                  Putty In My Hands
# 1790                                Under the Influence
# 1830                      Something to Spill (A Secret)
# 3236                             To Whom It May Concern
# 3475                                        Lunch Break
# 3496                                        Sweet Touch
# 3507                                              Tease
# 3636  Serizawa and Reigen's Idiot Proof Guide to Dat...
# 3647                              it starts with a kiss
# 3706         Dirty Mind, Dirty Mouth, Dirty Little Head
# 3817                                          Full Moon
# 3900                                              munch
# 4049                           Beyond Forest and Thighs
# 4083                                 I Think I Love You
# 4147                                              Cover
# 4157                                     Sunday Morning
# 4175                         reigen gets eaten out lmao
# 4246                                      New Sensation
# 4296                                              Eager
# 4360                                  The Way You Dress
# 4734                                            Wedding
# 4782         Is It Gay To Help Your Boyfriend Jerk Off?
# 4852                              A Hymn for the Hidden
# 4890                            We're Taking Off, Baby~
# 4925  when the mirror breaks, i wouldn't miss it for...
# 4931                                 a little cuffed up
# 4973        hey wanna get a load of my ectoplasmic cum?
# 5006  if you burst into flames now will they call yo...
# 5054             tapped out, nothing left to talk about
#
#                      author  isAnon  isOrphan               id rating  \
# 16          Umbrella_Lemons   False     False  /works/47305864      E
# 212                 Tritrum   False     False  /works/46661461      E
# 491         rebelprincelynx   False     False  /works/45578944      T
# 554          localscattered   False     False  /works/44027950      T
# 793         viewm0nsterfinn   False     False  /works/44569366      N
# 864           WallaceWellls   False     False  /works/44166532      G
# 1195           unsleep_nsfw   False     False  /works/43625511      E
# 1449           Ollie_writes   False     False  /works/42759315      E
# 1563        MuffinsInSummer   False     False  /works/42287181      T
# 1765         orphan_account   False      True  /works/40555866      E
# 1790         orphan_account   False      True  /works/40160196      E
# 1830             Adamsapple   False     False  /works/39546333      G
# 3236            looneymoony   False     False  /works/22440022      M
# 3475                 hmmeid   False     False  /works/21178841      E
# 3496            SinkingSims   False     False  /works/21087989      E
# 3507                 hmmeid   False     False  /works/21046808      E
# 3636              PilotsRed   False     False  /works/17092823      G
# 3647         beefwellington   False     False  /works/20514137      E
# 3706            SinkingSims   False     False  /works/20312845      E
# 3817                 hmmeid   False     False  /works/19934380      E
# 3900       vitaminwaterzero   False     False  /works/19662496      E
# 4049            SinkingSims   False     False  /works/19097413      E
# 4083               cloudkin   False     False  /works/19012243      E
# 4147               cloudkin   False     False  /works/18880219      G
# 4157                 hmmeid   False     False  /works/18867520      M
# 4175              gayghosts   False     False  /works/18852481      E
# 4246                  Incog   False     False  /works/18748138      E
# 4296  GalacticConfectionist   False     False  /works/18680785      E
# 4360                   Hino   False     False  /works/18619120      G
# 4734         beefwellington   False     False  /works/18171371      G
# 4782             TRANSTOSHI   False     False  /works/18093443      E
# 4852                 Domoda   False     False  /works/17971514      G
# 4890             Kai_legacy   False     False  /works/17860775      N
# 4925         beefwellington   False     False  /works/17844437      T
# 4931             TRANSTOSHI   False     False  /works/17842076      E
# 4973             TRANSTOSHI   False     False  /works/17745770      E
# 5006         beefwellington   False     False  /works/17616347      T
# 5054         beefwellington   False     False  /works/17472140      G
#
#                                                warnings             category  \
# 16                          [No Archive Warnings Apply]                [M/M]
# 212                         [No Archive Warnings Apply]        [No category]
# 491                         [No Archive Warnings Apply]                [M/M]
# 554                    [Graphic Depictions Of Violence]                [M/M]
# 793                [Choose Not To Use Archive Warnings]        [No category]
# 864                         [No Archive Warnings Apply]                [M/M]
# 1195                                     [Rape/Non-Con]                [M/M]
# 1449                        [No Archive Warnings Apply]                [M/M]
# 1563  [Choose Not To Use Archive Warnings, No Archiv...                [M/M]
# 1765                        [No Archive Warnings Apply]                [M/M]
# 1790                        [No Archive Warnings Apply]                [M/M]
# 1830                        [No Archive Warnings Apply]                [M/M]
# 3236                        [No Archive Warnings Apply]                [Gen]
# 3475                        [No Archive Warnings Apply]                [M/M]
# 3496                        [No Archive Warnings Apply]                [M/M]
# 3507                        [No Archive Warnings Apply]                [M/M]
# 3636                        [No Archive Warnings Apply]           [Gen, M/M]
# 3647                        [No Archive Warnings Apply]                [M/M]
# 3706                        [No Archive Warnings Apply]                [M/M]
# 3817                        [No Archive Warnings Apply]                [M/M]
# 3900                        [No Archive Warnings Apply]                [M/M]
# 4049                        [No Archive Warnings Apply]                [M/M]
# 4083                        [No Archive Warnings Apply]                [M/M]
# 4147                        [No Archive Warnings Apply]  [M/M, Multi, Other]
# 4157                        [No Archive Warnings Apply]                [M/M]
# 4175                        [No Archive Warnings Apply]                [M/M]
# 4246                        [No Archive Warnings Apply]                [M/M]
# 4296                        [No Archive Warnings Apply]                [M/M]
# 4360                        [No Archive Warnings Apply]                [Gen]
# 4734                        [No Archive Warnings Apply]                [M/M]
# 4782                        [No Archive Warnings Apply]                [M/M]
# 4852                        [No Archive Warnings Apply]                [F/F]
# 4890  [Choose Not To Use Archive Warnings, No Archiv...  [Gen, Multi, Other]
# 4925                        [No Archive Warnings Apply]                [M/M]
# 4931                        [No Archive Warnings Apply]                [M/M]
# 4973                        [No Archive Warnings Apply]                [M/M]
# 5006                        [No Archive Warnings Apply]                [M/M]
# 5054                        [No Archive Warnings Apply]                [M/M]
#
#       isWip lastUpdated  ... intendedChapters  kudos   hits comments  \
# 16    False  2023-05-20  ...                1     41    359        6
# 212    True  2023-04-22  ...                ?      8    152        0
# 491   False  2023-03-08  ...                1     44    568        6
# 554    True  2023-02-27  ...                ?    110   1409       12
# 793   False  2023-01-27  ...                1     30    313        4
# 864    True  2023-01-17  ...                ?     66    783       18
# 1195  False  2022-12-15  ...                1      9    353        0
# 1449  False  2022-10-31  ...                1    142   2515        5
# 1563  False  2022-10-10  ...                1     21    557        1
# 1765  False  2022-07-25  ...                1    239   3412       18
# 1790  False  2022-07-08  ...                1    215   4111       26
# 1830  False  2022-06-10  ...                1    316   1970       15
# 3236  False  2020-01-27  ...                1     59    408       10
# 3475  False  2019-10-26  ...                1    162   3899        8
# 3496  False  2019-10-19  ...                1    176   2662        8
# 3507  False  2019-10-15  ...                1    125   3367       12
# 3636   True  2019-09-07  ...               10    950  10328      162
# 3647  False  2019-09-04  ...                1     67   1637        7
# 3706  False  2019-08-19  ...                1    259   3254        6
# 3817  False  2019-07-23  ...                1     91   2255        3
# 3900  False  2019-07-06  ...                1    204   3237        7
# 4049  False  2019-06-04  ...                1    127   3407       11
# 4083   True  2019-05-29  ...                ?     16    247        2
# 4147  False  2019-05-19  ...                1    108    688       12
# 4157  False  2019-05-18  ...                1    108   1869        2
# 4175  False  2019-05-16  ...                1    173   3996       13
# 4246  False  2019-05-07  ...                1    173   4032        9
# 4296  False  2019-05-02  ...                1    231   4583       15
# 4360  False  2019-04-27  ...                1    303   1385       13
# 4734  False  2019-03-19  ...                1    131   1249       19
# 4782  False  2019-03-13  ...                1    260   5549       25
# 4852  False  2019-03-02  ...                1    130   1011        7
# 4890   True  2019-02-25  ...                ?     45   1027       14
# 4925  False  2019-02-19  ...                2    209   1813       26
# 4931  False  2019-02-18  ...                1    206   5647        8
# 4973  False  2019-02-11  ...                1    100   3061        4
# 5006  False  2019-02-03  ...                2    313   2583       24
# 5054  False  2019-01-19  ...                1    432   3090       29
#
#       bookmarks collections kudos_per_hits       date  numSeries  \
# 16            3           0       0.114206 2023-05-20          0
# 212           0           0       0.052632 2023-04-22          0
# 491           6           0       0.077465 2023-03-08          0
# 554          17           0       0.078070 2023-02-27          0
# 793           3           0       0.095847 2023-01-27          0
# 864           7           0       0.084291 2023-01-17          0
# 1195          0           0       0.025496 2022-12-15          0
# 1449          7           0       0.056461 2022-10-31          0
# 1563          0           0       0.037702 2022-10-10          0
# 1765         25           0       0.070047 2022-07-25          1
# 1790         15           0       0.052299 2022-07-08          1
# 1830         31           0       0.160406 2022-06-10          0
# 3236          9           0       0.144608 2020-01-27          0
# 3475         12           0       0.041549 2019-10-26          0
# 3496          8           0       0.066116 2019-10-19          0
# 3507         11           0       0.037125 2019-10-15          0
# 3636         98           0       0.091983 2019-09-07          0
# 3647          1           0       0.040929 2019-09-04          1
# 3706         14           0       0.079594 2019-08-19          0
# 3817          3           0       0.040355 2019-07-23          0
# 3900         13           0       0.063021 2019-07-06          0
# 4049         12           0       0.037276 2019-06-04          0
# 4083          1           0       0.064777 2019-05-29          0
# 4147          9           0       0.156977 2019-05-19          1
# 4157          7           0       0.057785 2019-05-18          0
# 4175         15           0       0.043293 2019-05-16          0
# 4246         14           0       0.042907 2019-05-07          0
# 4296         13           0       0.050404 2019-05-02          0
# 4360         28           0       0.218773 2019-04-27          0
# 4734         12           0       0.104884 2019-03-19          1
# 4782         16           0       0.046855 2019-03-13          1
# 4852         15           0       0.128586 2019-03-02          0
# 4890          2           0       0.043817 2019-02-25          0
# 4925         16           0       0.115279 2019-02-19          1
# 4931         20           0       0.036480 2019-02-18          0
# 4973          6           0       0.032669 2019-02-11          1
# 5006         34           0       0.121177 2019-02-03          1
# 5054         35           0       0.139806 2019-01-19          1
#
#                                                ffstring
# 16    POV Reigen Arataka,Soft Dom Reigen Arataka,Ser...
# 212   Dom/sub,Trans Serizawa Katsuya,Praise Kink,Ove...
# 491   Trans Male Character,Trans Serirei,Trans Reige...
# 554   Takes place right after Reigen runs from Seriz...
# 793   Implied/Referenced Self-Harm,Talking,Mid-Canon...
# 864   Chronic Pain,working through internalized able...
# 1195  vine sex,technically noncon,takes place in dim...
# 1449  Trans Male Character,Trans Reigen Arataka,Tran...
# 1563  Psychic Bond,Unplanned Pregnancy,Mpreg,Empath ...
# 1765  Getting Together,First Dates,Drunkenness,Expli...
# 1790  Porn With Plot,Case Fic,Curse Breaking,Fuck Or...
# 1830  Trans Reigen Arataka,Trans Serizawa Katsuya,Tr...
# 3236  he has kids but theyre in the background liter...
# 3475  Collars,Leashes,not exactly petplay just the u...
# 3496  funny then horny then sappy,a tried and truste...
# 3507  Cunnilingus,Vibrators,Bondage,Dom Reigen,Sub S...
# 3636  Getting Together,Mutual Pining,mutual obliviou...
# 3647  Hand Jobs,Kissing,Trans Reigen,Trans Serizawa,...
# 3706  porn with bare minimum plot,Established Relati...
# 3817  Werewolf Seri,Trans Reigen,Trans Serizawa,Cunn...
# 3900  Trans Reigen,Trans Serizawa,Trans Character,Tr...
# 4049  Porn with Feelings,buildup babey!,lots of fore...
# 4083  HAHAHA I WROTE IT,uh. dare i call this the fuc...
# 4147  Polyamory,Pre-Poly,Trans Serizawa Katsuya,Nonb...
# 4157  Fluff,Vibrators,Using powers during sex,Cuddli...
# 4175  NSFW,Plot What Plot/Porn Without Plot,Smut,Flu...
# 4246  Trans Male Character,Trans Reigen Arataka,Tran...
# 4296  Trans Seri,Office Sex,Semi-Public Sex,Cunnilin...
# 4360  Trans Reigen,Trans Serizawa,Spirits and Such f...
# 4734  Weddings,Wedding Planning,Trans Serizawa,Trans...
# 4782  Trans Male Character,Trans Reigen,Trans Seriza...
# 4852  Genderbending,Alternate Universe - Always a Di...
# 4890  Teru's trans here,slight misgendering but it's...
# 4925  Trans Character,Trans Reigen,Trans Serizawa,Fl...
# 4931  Trans Male Character,Trans Reigen,Trans Seriza...
# 4973  Trans Male Character,Trans Serizawa,Bottom Ser...
# 5006  Trans Character,Trans Serizawa,Character Study...
# 5054  Trans Male Character,Trans Reigen,Trans Seriza...
#
# [38 rows x 29 columns]

# %%
# what pct of fics contain fluff
fluff= str_df[str_df.ffstring.str.contains('Fluff', regex=True, flags=re.IGNORECASE)]
len(fluff) / len(df)
# Out:
# 0.2704420279621522

# %%
hurt = str_df[str_df.ffstring.str.contains('Hurt', regex=True, flags=re.IGNORECASE)]
len(hurt) / len(df)
# Out:
# 0.16085298686626182

# %%
#fluff vs hurt

# %%
trans = str_df[str_df.ffstring.str.contains('Trans', regex=True, flags=re.IGNORECASE)]
len(trans) / len(df)
# Out:
# 0.05309984465470979

# %%
# graph time series trans characters date vs number of works
trans_ts = trans[['date', 'title']].groupby(by=[trans.date.dt.year,trans.date.dt.month])['title']
trans_ts.count().plot()
# Out:
# <AxesSubplot:xlabel='date,date'>

# %%
import datetime
post_2016 = df[df['date'] > '2016-10-01']
post_2016 = df[['date', 'title']].groupby(by=[post_2016.date.dt.year, post_2016.date.dt.month])['title']
post_2016.count().plot()
# Out:
# <AxesSubplot:xlabel='date,date'>

# %%
# what pct of fics in jan were tagged trans?
post_2016.count()
# Out:
# date    date
# 2016.0  10.0     85
#         11.0    107
#         12.0    146
# 2017.0  1.0      94
#         2.0      94
#                ...
# 2023.0  1.0     263
#         2.0     210
#         3.0     206
#         4.0     184
#         5.0     158
# Name: title, Length: 80, dtype: int64

# %%
trans_ts.count()
# Out:
# date  date
# 2016  10       2
#       12       2
# 2017  1        2
#       3        1
#       4        3
#               ..
# 2023  1       25
#       2       24
#       3       22
#       4       22
#       5       11
# Name: title, Length: 71, dtype: int64

# %%
nb = str_df[str_df.ffstring.str.contains('Nonbinary', regex=True, flags=re.IGNORECASE)]
len(nb) / len(df)
# Out:
# 0.010591724332721366

# %%
not_minegishi_nb = nb[~nb.ffstring.str.contains('Nonbinary Minegishi Toshiki|Nonbinary Minegishi', regex=True, flags=re.IGNORECASE)]
not_minegishi_nb[['title', 'author', 'id', 'freeforms']]
# Out:
#                                                   title              author  \
# 2844                                      Something Bad            W3LTERW8
# 2927                                      Waking You Up      orphan_account
# 2948                                          Undercuts      orphan_account
# 3433  swimming with a shark isn’t as scary as you think       distraitLoser
# 3503                                 Faces in the Crowd            W3LTERW8
# 3590                     So You Won't See Me Unraveling            W3LTERW8
# 3613                                       So Punk Rock           Felidaeng
# 3808                                   Excuses, Excuses            W3LTERW8
# 4002  Your house is on fire and your children are go...               eggio
# 4102                                      Haunted House  morosexualserizawa
# 4173                                   breakfast in bed          swearizawa
# 4177    turn soft and lovely any time you have a chance          swearizawa
# 4258                                      Rainbow Socks  morosexualserizawa
# 4368                                               Real            W3LTERW8
# 4486          Space and Time and Ball-and-Socket Joints            W3LTERW8
# 4638                                           Flexible            W3LTERW8
# 4693  We're hangin' with the girls that look like bo...    ok_but_first_tea
# 4720                                          Like Mind            W3LTERW8
# 4822                                       Sense Memory            W3LTERW8
# 5036                                                Raw            W3LTERW8
# 5206                                          Rosy Pink            W3LTERW8
# 5291                           Fabric Color Texture Mob          beefstatic
# 5302                                      Frayed String            W3LTERW8
# 5334                                        Best Friend          beefstatic
# 5529                    Cluttered Spaces (Discontinued)          beefstatic
# 5854                              Deprivation Isolation          beefstatic
#
#                    id                                          freeforms
# 2844  /works/25564741  [Hook-Up, Pining, LGBTQ Themes, Nonbinary Char...
# 2927  /works/21766069  [Age Swap AU, This is a rewrite of the 7th div...
# 2948  /works/24585385  [Fluff, Pining, Mutual Pining, Haircuts, Misun...
# 3433  /works/21379699  [post-claw, Established Relationship, Oceanari...
# 3503  /works/21065936  [Public Sex, Train Sex, Vaginal Fingering, Fin...
# 3590  /works/20730341  [Trans Male Character, Menstruation, Hurt/Comf...
# 3613  /works/20626772  [Suzuki Shou-centric, Suzuki Shou Has ADHD, sh...
# 3808  /works/19950475  [Vibrators, Semi-Public Sex, Sex Toys Under Cl...
# 4002  /works/18529276  [Angst, Hurt/Comfort, Past Child Abuse, Implie...
# 4102  /works/18965431  [Haunted Houses, Case Fic, Mutual Pining, Pre-...
# 4173  /works/18855151  [Fluff without Plot, Nonbinary Character, idk ...
# 4177  /works/18849763  [Fluff without Plot, Hurt/Comfort, i guess lol...
# 4258  /works/18662395  [Fluff, Pride, reigen and serizawa dad gang, S...
# 4368  /works/18600040  [Trans Reigen, Nonbinary Character, Nonbinary ...
# 4486  /works/18448316  [Coming Out, Nonbinary Character, Gender Ident...
# 4638  /works/18280835  [Hook-Up, Developing Relationship, Threesome -...
# 4693  /works/18211730  [Trans Mob, Trans Ritsu, nonbinary mob, Gender...
# 4720  /works/18182549  [Trauma, Developing Friendships, Nightmares, D...
# 4822  /works/18033125  [Tattoos, Needles, Yakuza, Hook-Up, Mutual Mas...
# 5036  /works/17513870  [Trans Male Character, Trans Character, Transp...
# 5206  /works/16444304  [Trans Character, Nonbinary Character, Drinkin...
# 5291  /works/15862959  [other characters mentioned but its just mob, ...
# 5302  /works/15755751  [Gender Dysphoria, Body Dysphoria, Dialogue He...
# 5334  /works/15524403  [Best Friends, Esper and x files, mob and tome...
# 5529  /works/11764593  [Fluff, Intrigue, Angst, Hurt/Comfort, Sort Of...
# 5854  /works/11965254  [hey remember that cursed room that blocked po...

# %%
#nsfw stats
m_rated_fics = str_df[str_df['rating'] == 'M']
e_rated_fics = str_df[str_df['rating'] == 'E']

# %%
e_rated_fics
e_free = e_rated_fics.freeforms.tolist()
ctr = Counter(chain.from_iterable(e_free))
ctr.most_common(50)

y = [count for tag, count in ctr.most_common(50)]
x = [tag for tag, count in ctr.most_common(50)]

plt.bar(x, y, color='blue')
plt.title("Freeform Tag Frequency")
plt.ylabel("Frequency of Tag")
plt.xticks(rotation=90)
plt.show()

# %%
# serirei e-rated only
sr_e_free = sr[sr['rating'] == 'E']
ctr = Counter(chain.from_iterable(sr_e_free.freeforms.tolist()))
ctr.most_common(50)

y = [count for tag, count in ctr.most_common(50)]
x = [tag for tag, count in ctr.most_common(50)]

plt.bar(x, y, color='blue')
plt.title("Freeform Tag Frequency")
plt.ylabel("Frequency of Tag")
plt.xticks(rotation=90)
plt.show()

# %%
# trans serirei e-rated only
sr_e_trans_free = sr_e_free[sr_e_free.ffstring.str.contains('Trans', regex=True, flags=re.IGNORECASE)].freeforms.tolist()
ctr = Counter(chain.from_iterable(sr_e_trans_free))
ctr.most_common(50)

y = [count for tag, count in ctr.most_common(100)]
x = [tag for tag, count in ctr.most_common(100)]

plt.bar(x, y, color='blue')
plt.title("Freeform Tag Frequency")
plt.ylabel("Frequency of Tag")
plt.xticks(rotation=90)
plt.show()
