# %%
import requests
import pandas as pd

file_url = 'https://raw.githubusercontent.com/ani-exe/simple_ao3_scraper/main/outfile.json'
data = requests.get(file_url).json()
data = data['data']
df = pd.DataFrame(data)
df.dtypes
# Out:
# title               object
# author              object
# isAnon                bool
# isOrphan              bool
# id                  object
# rating              object
# warnings            object
# category            object
# isWip                 bool
# lastUpdated         object
# relationships       object
# isSlash               bool
# freeforms           object
# summary             object
# isSeries              bool
# seriesMeta          object
# language            object
# words                int64
# currentChapters      int64
# intendedChapters    object
# kudos                int64
# hits                 int64
# comments             int64
# bookmarks            int64
# collections          int64
# dtype: object

# %%
# kudos / hits can be useful for another view (altho favors newer works & oneshots)
# versus overall stats which favors multichap & older
# wonder what the balance would be here.

df = df.assign(kudos_per_hits = df.kudos / df.hits)
df['lastUpdated'] = pd.to_datetime(df['lastUpdated'])
df['rating'] = df['rating'].str[:1]

df = df.assign(numSeries = df['seriesMeta'].str.len())
df
# Out:
#                                               title  \
# 0                                             Trust
# 1     At The End of Everything (Hold Onto Anything)
# 2        Warmth Is in the Empty Spaces of the Heart
# 3                                            Tabata
# 4                              New Business Venture
# ...                                             ...
# 7059                             Double Team Tactic
# 7060                                              1
# 7061                               Brother's Keeper
# 7062                                         senses
# 7063                                     Of course.
#
#                          author  isAnon  isOrphan               id rating  \
# 0                    mikanviola   False     False  /works/47233843      T
# 1        FixhBones (Fish_Bones)   False     False  /works/47236459      T
# 2                    calfhooves   False     False  /works/47235577      T
# 3                      metukika   False     False  /works/46992460      G
# 4                  blue_avocado   False     False  /works/18739756      T
# ...                         ...     ...       ...              ...    ...
# 7059             orphan_account   False      True   /works/5782909      M
# 7060  slutreigen (pleasejustno)   False     False   /works/5613691      G
# 7061         allthingsunrelated   False     False   /works/5239292      N
# 7062           ekubo (apurochi)   False     False   /works/2535437      T
# 7063                  Anonymous    True     False  /works/40641009      N
#
#                                   warnings       category  isWip lastUpdated  \
# 0              [No Archive Warnings Apply]          [M/M]  False  2023-05-17
# 1              [No Archive Warnings Apply]     [Gen, M/M]  False  2023-05-17
# 2              [No Archive Warnings Apply]          [M/M]  False  2023-05-17
# 3              [No Archive Warnings Apply]          [M/M]  False  2023-05-17
# 4              [No Archive Warnings Apply]          [Gen]   True  2023-05-17
# ...                                    ...            ...    ...         ...
# 7059                            [Underage]          [M/M]  False  2016-01-22
# 7060           [No Archive Warnings Apply]  [No category]  False  2016-01-02
# 7061  [Choose Not To Use Archive Warnings]          [Gen]  False  2015-11-18
# 7062                            [Underage]          [M/M]  False  2014-10-30
# 7063  [Choose Not To Use Archive Warnings]          [M/M]  False  1969-07-29
#
#       ...  words  currentChapters intendedChapters kudos   hits comments  \
# 0     ...   2863                2                2     4     14        1
# 1     ...   1771                1                1     9     37        0
# 2     ...   2412                1                1     9     42        3
# 3     ...  13774                3                3    83    708       38
# 4     ...  44304                9                ?    23    320       10
# ...   ...    ...              ...              ...   ...    ...      ...
# 7059  ...   5281                1                1   792  12710       41
# 7060  ...    356                1                1   204   2221       15
# 7061  ...   1722                1                1   251   1931        7
# 7062  ...    266                1                1   172   2786        5
# 7063  ...    306                1                1    34    763        2
#
#      bookmarks  collections  kudos_per_hits numSeries
# 0            0            0        0.285714         0
# 1            1            0        0.243243         0
# 2            1            0        0.214286         0
# 3           10            0        0.117232         0
# 4            2            0        0.071875         0
# ...        ...          ...             ...       ...
# 7059        62            0        0.062313         0
# 7060         5            0        0.091851         1
# 7061        43            0        0.129984         0
# 7062         5            1        0.061737         0
# 7063         2            1        0.044561         0
#
# [7064 rows x 27 columns]

# %%
df.describe()
# Out:
#               words  currentChapters         kudos           hits  \
# count  7.064000e+03      7064.000000   7064.000000    7064.000000
# mean   6.590518e+03         2.178228    207.103907    2182.405011
# std    6.790334e+04        13.022827    395.214921    6097.343447
# min    1.000000e+02         1.000000      0.000000      11.000000
# 25%    1.148500e+03         1.000000     47.000000     487.000000
# 50%    2.269000e+03         1.000000    109.000000    1065.000000
# 75%    4.940500e+03         1.000000    225.250000    2236.000000
# max    5.440995e+06      1056.000000  12500.000000  386291.000000
#
#           comments    bookmarks  collections  kudos_per_hits    numSeries
# count  7064.000000  7064.000000  7064.000000     7064.000000  7064.000000
# mean     22.996319    23.256370     0.071631        0.110478     0.208805
# std     102.285764    70.852027     0.299548        0.050869     0.416462
# min       0.000000     0.000000     0.000000        0.000000     0.000000
# 25%       4.000000     3.000000     0.000000        0.071931     0.000000
# 50%       8.000000     8.000000     0.000000        0.105413     0.000000
# 75%      18.000000    21.000000     0.000000        0.142618     0.000000
# max    5886.000000  2703.000000     8.000000        0.475000     2.000000

# %%
numeric_stats = ["kudos", "hits", "comments", "bookmarks", "kudos_per_hits"]
rating_per_avg_stat = df[["rating"] + numeric_stats].groupby("rating").mean()
rating_per_avg_stat
# Out:
#              kudos         hits   comments  bookmarks  kudos_per_hits
# rating
# E       208.994012  3477.519960  17.473054  18.754491        0.061050
# G       206.848496  1632.233780  15.143530  22.006887        0.134563
# M       182.157706  2335.211470  38.611111  20.508961        0.084211
# N       125.886555  1190.884454  10.897059  11.903361        0.107240
# T       229.752755  2449.886294  33.682239  29.821067        0.110157

# %%
rating_per_avg_stat["kudos"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["comments"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["bookmarks"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["kudos_per_hits"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
rating_per_avg_stat["hits"].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
# do wips do worse than completed fics?
iswip_per_avg_stat = df[["isWip"] + numeric_stats].groupby("isWip").mean()
iswip_per_avg_stat
# Out:
#             kudos         hits   comments  bookmarks  kudos_per_hits
# isWip
# False  215.482325  2125.839395  18.790619  23.720258        0.115524
# True   165.325424  2464.466102  43.967797  20.943220        0.085314

# %%
#oneshots only
oneshot_avg_stats = df[df["intendedChapters"] == "1"]
oneshot_avg_stats.describe()
# Out:
#               words  currentChapters        kudos          hits     comments  \
# count   5176.000000           5176.0  5176.000000   5176.000000  5176.000000
# mean    2596.845247              1.0   186.205951   1705.160162    11.021638
# std     2671.258970              0.0   291.995072   2486.148905    15.056836
# min      100.000000              1.0     0.000000     20.000000     0.000000
# 25%      984.750000              1.0    49.000000    470.750000     3.000000
# 50%     1730.000000              1.0   108.000000    998.000000     7.000000
# 75%     3228.250000              1.0   215.000000   2005.000000    14.000000
# max    29089.000000              1.0  6424.000000  55854.000000   365.000000
#
#          bookmarks  collections  kudos_per_hits    numSeries
# count  5176.000000  5176.000000     5176.000000  5176.000000
# mean     18.465611     0.075348        0.119047     0.225077
# std      45.984084     0.277537        0.052576     0.428633
# min       0.000000     0.000000        0.000000     0.000000
# 25%       3.000000     0.000000        0.081063     0.000000
# 50%       7.000000     0.000000        0.117149     0.000000
# 75%      18.000000     0.000000        0.152174     0.000000
# max    1609.000000     4.000000        0.475000     2.000000

# %%
#multichap fics only
multichap_avg_stats = df[df["intendedChapters"] != "1"] # could be a number or a '?'
multichap_avg_stats.describe()
# Out:
#               words  currentChapters         kudos           hits  \
# count  1.888000e+03      1888.000000   1888.000000    1888.000000
# mean   1.753927e+04         5.408369    264.396186    3490.783898
# std    1.306717e+05        24.910631    588.496031   10948.357369
# min    1.220000e+02         1.000000      0.000000      11.000000
# 25%    2.929000e+03         2.000000     43.000000     564.750000
# 50%    6.615500e+03         3.000000    111.500000    1327.500000
# 75%    1.578325e+04         6.000000    268.000000    3181.500000
# max    5.440995e+06      1056.000000  12500.000000  386291.000000
#
#           comments    bookmarks  collections  kudos_per_hits    numSeries
# count  1888.000000  1888.000000  1888.000000     1888.000000  1888.000000
# mean     55.825212    36.390360     0.061441        0.086983     0.164195
# std     192.528139   112.939069     0.352802        0.036755     0.377634
# min       0.000000     0.000000     0.000000        0.000000     0.000000
# 25%       6.000000     3.000000     0.000000        0.060939     0.000000
# 50%      18.000000    11.000000     0.000000        0.082634     0.000000
# 75%      44.000000    29.000000     0.000000        0.109186     0.000000
# max    5886.000000  2703.000000     8.000000        0.290698     2.000000

# %%
#do fics in series have more engagement?
df[df["isSeries"]].describe()
# Out:
#               words  currentChapters        kudos          hits     comments  \
# count  1.446000e+03      1446.000000  1446.000000   1446.000000  1446.000000
# mean   1.056549e+04         2.746196   221.281466   2460.753112    30.145920
# std    1.479469e+05        28.005114   343.152826   4500.096121   177.881836
# min    1.000000e+02         1.000000     2.000000     25.000000     0.000000
# 25%    1.063000e+03         1.000000    66.000000    634.500000     4.000000
# 50%    2.094500e+03         1.000000   127.500000   1333.000000     9.500000
# 75%    4.907500e+03         1.000000   243.000000   2672.500000    19.000000
# max    5.440995e+06      1056.000000  4828.000000  65995.000000  5886.000000
#
#          bookmarks  collections  kudos_per_hits    numSeries
# count  1446.000000  1446.000000     1446.000000  1446.000000
# mean     20.919779     0.064315        0.104840     1.020055
# std      56.163853     0.274673        0.041388     0.140238
# min       0.000000     0.000000        0.005296     1.000000
# 25%       3.000000     0.000000        0.077239     1.000000
# 50%       8.000000     0.000000        0.102331     1.000000
# 75%      19.000000     0.000000        0.129826     1.000000
# max    1203.000000     4.000000        0.303704     2.000000
